# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '3ad520a3-8613-49b5-8eb0-284596de9723',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2024-10-22T18:20:17.241Z', 'error_code': 0, 'error_message': None, 'elapsed': 46, 'credit_count': 1, 'notice': None, 'total_count': 9836}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 11783, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'bitcoin-ecosystem', 'ftx-bankruptcy-estate'], 'max_supply': 21000000, 'circulating_supply': 19771478, 'total_supply': 19771478, 'infinite_supply': False, 'platform': None, 'cmc_rank': 1, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2024-10-22T18:18:00.000Z', 'quote': {'USD': {'price': 67286.22551265017, 'volume_24h': 33114566169.523186, 'volume_change_24h': -12.6902, 'percent_change_1h': 0.18523805, 'percent_change_24h': 0.03210561, 'percent_change_7d': 0.07747155, 'percent_change_30d': 6.99502326, 'percent_change_60d': 6.55580611, 'percent_change_90d': 1.17062593, 'market_cap': 1330348127426.4016, 'market_cap_dominance': 57.2231, 'fully_diluted_market_cap': 1413010735765.65, 'tvl': None, 'last_updated': '2024-10-22T18:18:00.000Z'}}}, {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'num_market_pairs': 9438, 'date_added': '2015-08-07T00:00:00.000Z', 'tags': ['pos', 'smart-contracts', 'ethereum-ecosystem', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'hashkey-capital-portfolio', 'kenetic-capital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'layer-1', 'ftx-bankruptcy-estate'], 'max_supply': None, 'circulating_supply': 120392960.0277458, 'total_supply': 120392960.0277458, 'infinite_supply': True, 'platform': None, 'cmc_rank': 2, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2024-10-22T18:18:00.000Z', 'quote': {'USD': {'price': 2624.633585393226, 'volume_24h': 15804383321.18304, 'volume_change_24h': -18.5256, 'percent_change_1h': 0.4157655, 'percent_change_24h': -1.42402568, 'percent_change_7d': 1.0704807, 'percent_change_30d': 1.88829358, 'percent_change_60d': -3.68739278, 'percent_change_90d': -23.16237577, 'market_cap': 315987406333.72577, 'market_cap_dominance': 13.5918, 'fully_diluted_market_cap': 315987406333.73, 'tvl': None, 'last_updated': '2024-10-22T18:18:00.000Z'}}}, {'id': 825, 'name': 'Tether USDt', 'symbol': 'USDT', 'slug': 'tether', 'num_market_pairs': 100900, 'date_added': '2015-02-25T00:00:00.000Z', 'tags': ['stablecoin', 'asset-backed-stablecoin', 'avalanche-ecosystem', 'solana-ecosystem', 'arbitrum-ecosytem', 'moonriver-ecosystem', 'injective-ecosystem', 'bnb-chain', 'usd-stablecoin', 'optimism-ecosystem', 'fiat-stablecoin'], 'max_supply': None, 'circulating_supply': 120219543500.33812, 'total_supply': 121337937370.43233, 'platform': {'id': 102 ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df = pd.json_normalize(data['data'])
df['timestamp'] = pd.to_datetime('now')
df
# Out:
#        id          name symbol          slug  num_market_pairs  \
# 0       1       Bitcoin    BTC       bitcoin             11783
# 1    1027      Ethereum    ETH      ethereum              9438
# 2     825   Tether USDt   USDT        tether            100900
# 3    1839           BNB    BNB           bnb              2266
# 4    5426        Solana    SOL        solana               768
# 5    3408          USDC   USDC      usd-coin             22592
# 6      52           XRP    XRP           xrp              1407
# 7      74      Dogecoin   DOGE      dogecoin              1084
# 8    1958          TRON    TRX          tron              1054
# 9   11419       Toncoin    TON       toncoin               582
# 10   2010       Cardano    ADA       cardano              1273
# 11   5805     Avalanche   AVAX     avalanche               790
# 12   5994     Shiba Inu   SHIB     shiba-inu               888
# 13   1975     Chainlink   LINK     chainlink              1861
# 14   1831  Bitcoin Cash    BCH  bitcoin-cash               935
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2017-07-25T00:00:00.000Z
# 4   2020-04-10T00:00:00.000Z
# 5   2018-10-08T00:00:00.000Z
# 6   2013-08-04T00:00:00.000Z
# 7   2013-12-15T00:00:00.000Z
# 8   2017-09-13T00:00:00.000Z
# 9   2021-08-26T13:40:22.000Z
# 10  2017-10-01T00:00:00.000Z
# 11  2020-07-13T00:00:00.000Z
# 12  2020-08-01T00:00:00.000Z
# 13  2017-09-20T00:00:00.000Z
# 14  2017-07-23T00:00:00.000Z
#
#                                                  tags    max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...           NaN
# 2   [stablecoin, asset-backed-stablecoin, avalanch...           NaN
# 3   [marketplace, centralized-exchange, payments, ...           NaN
# 4   [pos, platform, solana-ecosystem, cms-holdings...           NaN
# 5   [medium-of-exchange, stablecoin, asset-backed-...           NaN
# 6   [medium-of-exchange, enterprise-solutions, arr...  1.000000e+11
# 7   [mineable, pow, scrypt, medium-of-exchange, me...           NaN
# 8   [media, payments, tron-ecosystem, layer-1, dwf...           NaN
# 9   [pos, layer-1, ftx-bankruptcy-estate, dwf-labs...           NaN
# 10  [dpos, pos, platform, research, smart-contract...  4.500000e+10
# 11  [defi, smart-contracts, three-arrows-capital-p...  7.157487e+08
# 12      [memes, ethereum-ecosystem, doggone-doggerel]           NaN
# 13  [platform, defi, oracles, smart-contracts, sub...           NaN
# 14  [mineable, pow, sha-256, marketplace, medium-o...  2.100000e+07
#
#     circulating_supply  total_supply  infinite_supply  platform  cmc_rank  \
# 0         1.977148e+07  1.977148e+07            False       NaN         1
# 1         1.203930e+08  1.203930e+08             True       NaN         2
# 2         1.202195e+11  1.213379e+11             True       NaN         3
# 3         1.459314e+08  1.459314e+08            False       NaN         4
# 4         4.700072e+08  5.869844e+08             True       NaN         5
# 5         3.460591e+10  3.460591e+10            False       NaN         6
# 6         5.670644e+10  9.998712e+10            False       NaN         7
# 7         1.464758e+11  1.464758e+11             True       NaN         8
# 8         8.650560e+10  8.650564e+10             True       NaN         9
# 9         2.539545e+09  5.113677e+09             True       NaN        10
# 10        3.498097e+10  4.499512e+10            False       NaN        11
# 11        4.069581e+08  4.469612e+08            False       NaN        12
# 12        5.892671e+14  5.895183e+14            False       NaN        13
# 13        6.268500e+08  1.000000e+09            False       NaN        14
# 14        1.977779e+07  1.977779e+07            False       NaN        15
#
#     self_reported_circulating_supply  self_reported_market_cap tvl_ratio  \
# 0                                NaN                       NaN      None
# 1                                NaN                       NaN      None
# 2                                NaN                       NaN      None
# 3                                NaN                       NaN      None
# 4                                NaN                       NaN      None
# 5                                NaN                       NaN      None
# 6                                NaN                       NaN      None
# 7                                NaN                       NaN      None
# 8                       7.165966e+10              1.148174e+10      None
# 9                       3.414167e+09              1.788453e+10      None
# 10                               NaN                       NaN      None
# 11                               NaN                       NaN      None
# 12                               NaN                       NaN      None
# 13                               NaN                       NaN      None
# 14                               NaN                       NaN      None
#
#                 last_updated  quote.USD.price  quote.USD.volume_24h  \
# 0   2024-10-22T18:18:00.000Z     67286.225513          3.311457e+10
# 1   2024-10-22T18:18:00.000Z      2624.633585          1.580438e+10
# 2   2024-10-22T18:18:00.000Z         0.999312          6.011639e+10
# 3   2024-10-22T18:18:00.000Z       594.551092          1.743760e+09
# 4   2024-10-22T18:18:00.000Z       167.749582          3.604443e+09
# 5   2024-10-22T18:18:00.000Z         0.999819          6.850199e+09
# 6   2024-10-22T18:18:00.000Z         0.534654          1.090484e+09
# 7   2024-10-22T18:18:00.000Z         0.139629          1.678641e+09
# 8   2024-10-22T18:18:00.000Z         0.160226          3.082780e+08
# 9   2024-10-22T18:18:00.000Z         5.238328          1.720085e+08
# 10  2024-10-22T18:18:00.000Z         0.365776          3.126361e+08
# 11  2024-10-22T18:18:00.000Z        27.684486          2.977086e+08
# 12  2024-10-22T18:18:00.000Z         0.000018          2.762583e+08
# 13  2024-10-22T18:18:00.000Z        12.088140          3.268303e+08
# 14  2024-10-22T18:18:00.000Z       358.067043          2.152045e+08
#
#     quote.USD.volume_change_24h  quote.USD.percent_change_1h  \
# 0                      -12.6902                     0.185238
# 1                      -18.5256                     0.415766
# 2                      -13.7905                    -0.021481
# 3                      -11.7383                     0.082438
# 4                      -16.2976                     0.325222
# 5                        2.1781                    -0.035175
# 6                      -19.4769                     0.434612
# 7                      -19.2324                     1.468216
# 8                       -4.1783                     0.162260
# 9                      -10.4585                     0.398809
# 10                       4.8967                     1.396719
# 11                      -3.5200                     0.666341
# 12                     -32.2130                     0.710981
# 13                      50.1625                     0.655936
# 14                     -22.4708                     0.643305
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                       0.032106                     0.077472
# 1                      -1.424026                     1.070481
# 2                      -0.011874                    -0.047473
# 3                      -0.593972                     0.236711
# 4                       1.446194                     7.886587
# 5                      -0.002362                    -0.017585
# 6                      -2.297261                    -1.815696
# 7                      -1.751543                    20.205740
# 8                       1.270427                     1.022547
# 9                       0.604723                     0.307588
# 10                      2.351566                     1.581055
# 11                     -0.010192                    -2.581010
# 12                     -0.434882                     0.726038
# 13                      3.397186                     6.294914
# 14                     -1.354806                     0.764890
#
#     quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 0                       6.995023                      6.555806
# 1                       1.888294                     -3.687393
# 2                      -0.105919                     -0.110686
# 3                       1.906344                      1.552529
# 4                      16.266843                     12.636833
# 5                      -0.048311                     -0.051499
# 6                      -9.418955                    -11.848225
# 7                      31.253912                     24.472659
# 8                       5.785209                      1.560204
# 9                      -6.157453                    -21.411129
# 10                      4.535145                     -5.353044
# 11                      2.450197                      4.312601
# 12                     25.995779                     21.046555
# 13                      8.959707                      1.610347
# 14                      4.877442                     -0.950634
#
#     quote.USD.percent_change_90d  quote.USD.market_cap  \
# 0                       1.170626          1.330348e+12
# 1                     -23.162376          3.159874e+11
# 2                      -0.145597          1.201368e+11
# 3                       1.713668          8.676367e+10
# 4                      -7.079488          7.884352e+10
# 5                      -0.058715          3.459966e+10
# 6                     -14.232103          3.031830e+10
# 7                       5.825376          2.045221e+10
# 8                      19.333096          1.386044e+10
# 9                     -24.973108          1.330297e+10
# 10                    -11.592406          1.279521e+10
# 11                     -5.103229          1.126642e+10
# 12                      5.549965          1.076507e+10
# 13                    -12.721256          7.577450e+09
# 14                     -2.914591          7.081776e+09
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                          57.2231                        1.413011e+12
# 1                          13.5918                        3.159874e+11
# 2                           5.1692                        1.212544e+11
# 3                           3.7332                        8.676367e+10
# 4                           3.3930                        9.846638e+10
# 5                           1.4887                        3.459966e+10
# 6                           1.3041                        5.346535e+10
# 7                           0.8797                        2.045221e+10
# 8                           0.5962                        1.386045e+10
# 9                           0.5722                        2.678712e+10
# 10                          0.5504                        1.645994e+10
# 11                          0.4848                        1.981514e+10
# 12                          0.4630                        1.076966e+10
# 13                          0.3260                        1.208814e+10
# 14                          0.3046                        7.519408e+09
#
#    quote.USD.tvl    quote.USD.last_updated  platform.id platform.name  \
# 0           None  2024-10-22T18:18:00.000Z          NaN           NaN
# 1           None  2024-10-22T18:18:00.000Z          NaN           NaN
# 2           None  2024-10-22T18:18:00.000Z       1027.0      Ethereum
# 3           None  2024-10-22T18:18:00.000Z          NaN           NaN
# 4           None  2024-10-22T18:18:00.000Z          NaN           NaN
# 5           None  2024-10-22T18:18:00.000Z       1027.0      Ethereum
# 6           None  2024-10-22T18:18:00.000Z          NaN           NaN
# 7           None  2024-10-22T18:18:00.000Z          NaN           NaN
# 8           None  2024-10-22T18:18:00.000Z          NaN           NaN
# 9           None  2024-10-22T18:18:00.000Z          NaN           NaN
# 10          None  2024-10-22T18:18:00.000Z          NaN           NaN
# 11          None  2024-10-22T18:18:00.000Z          NaN           NaN
# 12          None  2024-10-22T18:18:00.000Z       1027.0      Ethereum
# 13          None  2024-10-22T18:18:00.000Z       1027.0      Ethereum
# 14          None  2024-10-22T18:18:00.000Z          NaN           NaN
#
#    platform.symbol platform.slug                      platform.token_address  \
# 0              NaN           NaN                                         NaN
# 1              NaN           NaN                                         NaN
# 2              ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3              NaN           NaN                                         NaN
# 4              NaN           NaN                                         NaN
# 5              ETH      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 6              NaN           NaN                                         NaN
# 7              NaN           NaN                                         NaN
# 8              NaN           NaN                                         NaN
# 9              NaN           NaN                                         NaN
# 10             NaN           NaN                                         NaN
# 11             NaN           NaN                                         NaN
# 12             ETH      ethereum  0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce
# 13             ETH      ethereum  0x514910771af9ca656af840dff83e8264ecf986ca
# 14             NaN           NaN                                         NaN
#
#                     timestamp
# 0  2024-10-22 14:20:17.293984
# 1  2024-10-22 14:20:17.293984
# 2  2024-10-22 14:20:17.293984
# 3  2024-10-22 14:20:17.293984
# 4  2024-10-22 14:20:17.293984
# 5  2024-10-22 14:20:17.293984
# 6  2024-10-22 14:20:17.293984
# 7  2024-10-22 14:20:17.293984
# 8  2024-10-22 14:20:17.293984
# 9  2024-10-22 14:20:17.293984
# 10 2024-10-22 14:20:17.293984
# 11 2024-10-22 14:20:17.293984
# 12 2024-10-22 14:20:17.293984
# 13 2024-10-22 14:20:17.293984
# 14 2024-10-22 14:20:17.293984

# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json
import os
from time import sleep

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '3ad520a3-8613-49b5-8eb0-284596de9723',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
  
df2 = pd.json_normalize(data['data'])
df2['Timestamp'] = pd.to_datetime('now')
df = pd.concat([df, df2], ignore_index=True)

    # Write DataFrame to CSV
file_path = r'/Users/marlonthompson/Desktop/Crypto/Crypto2.csv'
if not os.path.isfile(file_path):
        df.to_csv(file_path, index=False, header=True)
else:
        df.to_csv(file_path, mode='a', index=False, header=False)
# Out:
# {'status': {'timestamp': '2024-10-22T18:20:17.375Z', 'error_code': 0, 'error_message': None, 'elapsed': 21, 'credit_count': 1, 'notice': None, 'total_count': 9836}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 11783, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'bitcoin-ecosystem', 'ftx-bankruptcy-estate'], 'max_supply': 21000000, 'circulating_supply': 19771478, 'total_supply': 19771478, 'infinite_supply': False, 'platform': None, 'cmc_rank': 1, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2024-10-22T18:18:00.000Z', 'quote': {'USD': {'price': 67286.22551265017, 'volume_24h': 33114566169.523186, 'volume_change_24h': -12.6902, 'percent_change_1h': 0.18523805, 'percent_change_24h': 0.03210561, 'percent_change_7d': 0.07747155, 'percent_change_30d': 6.99502326, 'percent_change_60d': 6.55580611, 'percent_change_90d': 1.17062593, 'market_cap': 1330348127426.4016, 'market_cap_dominance': 57.2231, 'fully_diluted_market_cap': 1413010735765.65, 'tvl': None, 'last_updated': '2024-10-22T18:18:00.000Z'}}}, {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'num_market_pairs': 9438, 'date_added': '2015-08-07T00:00:00.000Z', 'tags': ['pos', 'smart-contracts', 'ethereum-ecosystem', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'hashkey-capital-portfolio', 'kenetic-capital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'layer-1', 'ftx-bankruptcy-estate'], 'max_supply': None, 'circulating_supply': 120392960.0277458, 'total_supply': 120392960.0277458, 'infinite_supply': True, 'platform': None, 'cmc_rank': 2, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2024-10-22T18:18:00.000Z', 'quote': {'USD': {'price': 2624.633585393226, 'volume_24h': 15804383321.18304, 'volume_change_24h': -18.5256, 'percent_change_1h': 0.4157655, 'percent_change_24h': -1.42402568, 'percent_change_7d': 1.0704807, 'percent_change_30d': 1.88829358, 'percent_change_60d': -3.68739278, 'percent_change_90d': -23.16237577, 'market_cap': 315987406333.72577, 'market_cap_dominance': 13.5918, 'fully_diluted_market_cap': 315987406333.73, 'tvl': None, 'last_updated': '2024-10-22T18:18:00.000Z'}}}, {'id': 825, 'name': 'Tether USDt', 'symbol': 'USDT', 'slug': 'tether', 'num_market_pairs': 100900, 'date_added': '2015-02-25T00:00:00.000Z', 'tags': ['stablecoin', 'asset-backed-stablecoin', 'avalanche-ecosystem', 'solana-ecosystem', 'arbitrum-ecosytem', 'moonriver-ecosystem', 'injective-ecosystem', 'bnb-chain', 'usd-stablecoin', 'optimism-ecosystem', 'fiat-stablecoin'], 'max_supply': None, 'circulating_supply': 120219543500.33812, 'total_supply': 121337937370.43233, 'platform': {'id': 102 ...

# %%
for i in range(333):
    print(f'API Runner completed. Iteration: {i+1}')
    sleep(60)  # Wait for 60 seconds before the next request
exit()
# Out:
# API Runner completed. Iteration: 1
# API Runner completed. Iteration: 2
# API Runner completed. Iteration: 3
# API Runner completed. Iteration: 4
# API Runner completed. Iteration: 5
# API Runner completed. Iteration: 6
# API Runner completed. Iteration: 7
# API Runner completed. Iteration: 8
# API Runner completed. Iteration: 9
# API Runner completed. Iteration: 10
# API Runner completed. Iteration: 11
# API Runner completed. Iteration: 12
# API Runner completed. Iteration: 13
# API Runner completed. Iteration: 14
# API Runner completed. Iteration: 15
# API Runner completed. Iteration: 16
# API Runner completed. Iteration: 17
# API Runner completed. Iteration: 18
# API Runner completed. Iteration: 19
# API Runner completed. Iteration: 20
# API Runner completed. Iteration: 21
# API Runner completed. Iteration: 22
# API Runner completed. Iteration: 23
# API Runner completed. Iteration: 24
# API Runner completed. Iteration: 25
# API Runner completed. Iteration: 26
# API Runner completed. Iteration: 27
# API Runner completed. Iteration: 28
# API Runner completed. Iteration: 29
# API Runner completed. Iteration: 30
# API Runner completed. Iteration: 31
# API Runner completed. Iteration: 32
# API Runner completed. Iteration: 33
# API Runner completed. Iteration: 34
# API Runner completed. Iteration: 35
# API Runner completed. Iteration: 36
# API Runner completed. Iteration: 37
# API Runner completed. Iteration: 38
# API Runner completed. Iteration: 39
# API Runner completed. Iteration: 40
# API Runner completed. Iteration: 41
# API Runner completed. Iteration: 42
# API Runner completed. Iteration: 43
# API Runner completed. Iteration: 44
# API Runner completed. Iteration: 45
# API Runner completed. Iteration: 46
# API Runner completed. Iteration: 47
# API Runner completed. Iteration: 48
# API Runner completed. Iteration: 49
# API Runner completed. Iteration: 50
# API Runner completed. Iteration: 51
# API Runner completed. Iteration: 52
# API Runner completed. Iteration: 53
# API Runner completed. Iteration: 54
# API Runner completed. Iteration: 55
# API Runner completed. Iteration: 56
# API Runner completed. Iteration: 57
# API Runner completed. Iteration: 58
# API Runner completed. Iteration: 59
# API Runner completed. Iteration: 60
# API Runner completed. Iteration: 61
# API Runner completed. Iteration: 62
# API Runner completed. Iteration: 63
# API Runner completed. Iteration: 64
# API Runner completed. Iteration: 65
# API Runner completed. Iteration: 66
# API Runner completed. Iteration: 67
# API Runner completed. Iteration: 68
# API Runner completed. Iteration: 69
# API Runner completed. Iteration: 70
# API Runner completed. Iteration: 71
# API Runner completed. Iteration: 72
# API Runner completed. Iteration: 73
# API Runner completed. Iteration: 74
# API Runner completed. Iteration: 75
# API Runner completed. Iteration: 76
# API Runner completed. Iteration: 77
# API Runner completed. Iteration: 78
# API Runner completed. Iteration: 79
# API Runner completed. Iteration: 80
# API Runner completed. Iteration: 81
# API Runner completed. Iteration: 82
# API Runner completed. Iteration: 83
# API Runner completed. Iteration: 84
# API Runner completed. Iteration: 85
# API Runner completed. Iteration: 86
# API Runner completed. Iteration: 87
# API Runner completed. Iteration: 88
# API Runner completed. Iteration: 89
# API Runner completed. Iteration: 90

# %%
df72 = pd.read_csv(r'/Users/marlonthompson/Desktop/Crypto/Crypto2.csv')
df72

# %%
df

# %%
df3 = df.groupby('name', sort=False)[['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d']].mean()
df3

# %%
df4 = df3.stack()
df4

# %%
df5 = df4.to_frame(name='values')
df5.count()
df5

# %%
index = pd.Index(range(90))
df6 = df5.reset_index()
df6

# %%
df7 = df6.rename(columns={'level_1': 'percent_change'})
df7

# %%
df7 = df6.rename(columns = {'level_1':'percent_change'})
df7

# %%
df7['percent_change'] = df7['percent_change'].replace({
    'quote.USD.percent_change_1h': '1hr',
    'quote.USD.percent_change_24h': '24hr',
    'quote.USD.percent_change_7d': '7d',
    'quote.USD.percent_change_30d': '30d',
    'quote.USD.percent_change_60d': '60d',
    'quote.USD.percent_change_90d': '90d'
})
df7

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.catplot(x='percent_change', y='values', hue='name', data=df7, kind ='point')
